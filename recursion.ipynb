# %%
# def factorial(num):
#     total = 1
#     while num > 0:
#         total = total * num
#         num += -1
#     return total

# answer = factorial(4)
# print(answer)


# def countdown_loop(n):
#     if n == 1:
#         return 1
#     while n > 0:
#         print(n)
#         n += -1

# countdown_loop(5)



def countdown(n):
    if n == 0:
        return 
    print(n)
    countdown(n-1)

countdown(5)
# Out:
# 5
# 4
# 3
# 2
# 1
