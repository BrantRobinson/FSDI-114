# %%
numbers = [1,2,3,4,5]
copy = []
reversed = []

while numbers:
    copy.append(numbers.pop(0))

while copy:
    print(copy)
    for n in range(len(copy) - 1):
        copy.append(copy.pop(0))
        print(f"copy {copy}")
    reversed.append(copy.pop(0))
    print(f"reversed {reversed}")

print(f"final {reversed}")
# Out:
# [1, 2, 3, 4, 5]
# copy [2, 3, 4, 5, 1]
# copy [3, 4, 5, 1, 2]
# copy [4, 5, 1, 2, 3]
# copy [5, 1, 2, 3, 4]
# reversed [5]
# [1, 2, 3, 4]
# copy [2, 3, 4, 1]
# copy [3, 4, 1, 2]
# copy [4, 1, 2, 3]
# reversed [5, 4]
# [1, 2, 3]
# copy [2, 3, 1]
# copy [3, 1, 2]
# reversed [5, 4, 3]
# [1, 2]
# copy [2, 1]
# reversed [5, 4, 3, 2]
# [1]
# reversed [5, 4, 3, 2, 1]
# final [5, 4, 3, 2, 1]

# %%
queue = []
if not queue:
    print("Queue is empty")
else: 
    print(f"Queue: {queue}")
# Out:
# Queue: [2]

# %%
queue = []
queue.append(5)
queue.append(6)
queue.append(7)
queue.append(8)

print(queue)
dequeue = queue.pop(0)

print(f"removed: {dequeue}, final queue: {queue}")
# Out:
# [5, 6, 7, 8]
# removed: 5, final queue: [6, 7, 8]

# %%
import queue
q = queue.Queue()
q.put(5)
q.put(6)
q.put(7)
q.put(8)

first = q.get()
print(first)
print(q.)????
# Out:
# 5
# ...

# %%
# Challenge #5

queue = []
queue.append(10)
queue.append(20)
queue.append(30)

print(queue)
# Out:
# [10, 20, 30]

# %% [markdown]
# List Slicing Cheat Sheet:
# list[:]             >> All
# list[Low:]          >> Low to End
# list[:High]         >> Begining to High
# list[Low:High]      >> Low to High
# list[::Step]        >> Start to End with Step
# list[Low::Step]     >> Low to End with Step
# list[:High:Step]    >> Start to High with Step
# list[Low:High:Step] >> Low to High with Step

# %%
word = "HELLO"
stack = []
for letter in word:
    stack.append(letter)
reverse_word = ""
while stack:
    reverse_word += stack.pop()

print(reverse_word)
# Out:
# OLLEH

# %%
# Challenge #4
stack = ["h","e","l","l","o"]
reversed = []
for letter in stack:
    reversed.append(stack.pop())
print(reversed)

# THAT DIDN"T WORK!

#Attempt #2
stack = ["h","e","l","l","o"]
reversed = []
index=-1
for letter in stack:
    reversed.append(stack[index])
    index -= 1
print (reversed)

# while loop
stack = ["h", "e", "l", "l", "o"]
reversed = []
while stack:
    reversed.append(stack.pop())
print(reversed)

#slicing - had to look this one up
stack = ["h", "e", "l", "l", "o"]
reversed = []
reversed = stack[::-1]
print(reversed)
# Out:
# ['o', 'l', 'l']
# ['o', 'l', 'l', 'e', 'h']
# ['o', 'l', 'l', 'e', 'h']
# ['o', 'l', 'l', 'e', 'h']

# %%
# Challenge #3 

stack = []

if not stack:
    print("Stack is empty")
else: 
    print(f"Stack: {stack}")
# Out:
# Stack: [12]

# %%
#Challenge #2 - push 4 numbers and print the top number without removing it

stack = [1, 2, 3, 4]
print (stack[-1])

# Alternate solution using list length
print (stack[len(stack)-1])
# Out:
# 4
# 4

# %%
stack = []

stack.append("A")
stack.append("B")
stack.append("C")

top = stack.pop()

print (f"stack: {stack}, removed: {top}")

top = stack.pop()
print (f"popped value: {top}")

print("Pushed 'D' into the stack")
stack.append("D")
print(stack)

top = stack.pop()
print (f"popped value: {top}")

print(f"remaining stack: {stack}")
# Out:
# stack: ['A', 'B'], removed: C
# popped value: B
# Pushed 'D' into the stack
# ['A', 'D']
# popped value: D
# remaining stack: ['A']
